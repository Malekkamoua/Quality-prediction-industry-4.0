# %% [markdown]
# <a href="https://colab.research.google.com/github/Malekkamoua/PFE/blob/main/Forecasting%20%7C%20Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install wandb -qqq
import wandb
wandb.login()

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Datascience/Datasets/final_dataset_fs_db.csv', parse_dates=['dates'],  index_col='dates',infer_datetime_format=True)
df.drop(['Unnamed: 0', 'Purity'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalization
values = df[['% Silica Concentrate']].values

# Normalization
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(values)

# %%
def create_data(series, prev_instances = 4):
 
    X_train_1 = pd.DataFrame(series).astype('float64')
    X_train_temp = X_train_1.shift(1)
    y_label = X_train_1.shift(-1)
    
    data = pd.concat([X_train_temp, X_train_1, y_label], axis=1)
    
    for r in range(prev_instances-2):
      X_train_temp = X_train_temp.shift(1)
      data = pd.concat([X_train_temp, data], axis=1)
    data.dropna(inplace = True)
    data.reset_index(drop = True, inplace = True)
    # print(data.head(10))
    X = data.iloc[:, 0:-1].values 
    y = data.iloc[:,-1].values 
    
    print('This series takes {} previous instances'.format(prev_instances))
    
    data.columns = [*data.columns[:-1], 'y']
    
    return data, X, y

# %%
WINDOW_SIZE = 5

time_series = scaled_data;
data, X, y = create_data(time_series, prev_instances = WINDOW_SIZE)
# Out:
# This series takes 5 previous instances

# %%
# 70% 15% 15%

X_train, y_train = X[:3935], y[:3935]
X_test, y_test = X[3935:4775], y[3935:4775]
X_val, y_val = X[4775:], y[4775:]
X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((3935, 5), (3935,), (840, 5), (840,), (841, 5), (841,))

# %%
# reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], WINDOW_SIZE,1))
X_test = X_test.reshape((X_test.shape[0], WINDOW_SIZE, 1))
X_val = X_val.reshape((X_val.shape[0], WINDOW_SIZE, 1))

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((3935, 5, 1), (3935,), (840, 5, 1), (840,), (841, 5, 1), (841,))

# %%
from statsmodels.tsa.stattools import acf

def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  
    mae = np.mean(np.abs(forecast - actual))    
    rmse = np.mean((forecast - actual)**2)**.5  

    return mape, mae, rmse

# %%
from keras import backend as K
from keras.layers import Layer, Input, LSTM
from keras.layers import Permute,TimeDistributed,Dense,Reshape,Activation,Lambda,Dropout
import math
import numpy as np


class MultiHeadedAttention():
    '''
    Self-Attention layer of Transformer block described in "Attention is all you need".
    d_model: the output dimensions for embeddings of each token in the sequence.
    heads  : number of heads 
    dim_q  : query vector and key vector dimensions
    dim_v  : value vector dimensions
    dropout_rate : dropout rate before fully connected layer
    '''
    def __init__(self,d_model ,heads,dim_q,dim_v,dropout_rate,name, **kwargs):
        self.heads=heads
        self.dim_q=dim_q
        self.dim_v=dim_q

        self.query_layer   = TimeDistributed(Dense(self.heads*self.dim_q,use_bias = False),name = name+'_QueryLayer')
        self.key_layer     = TimeDistributed(Dense(self.heads*self.dim_q,use_bias = False),name = name+'_KeyLayer')
        self.value_layer   = TimeDistributed(Dense(self.heads*self.dim_v,use_bias = False),name = name+'_ValueLayer') 

        self.dropout_layer = Dropout(dropout_rate)

        self.output_layer  = TimeDistributed(Dense(d_model,use_bias = False),name = name+'_AttentionOutputLayer')

    # moves up the timestep dimention towards the end and heads towards batch_size dimention
    def shift_timestep_ahead(self,vec,last_dim,time_steps,transpose=False):
      vec     = Reshape([-1,self.heads,last_dim])(vec)

      if transpose:
        vec   = Permute([2,3,1])(vec)
        vec   = Lambda(lambda x:K.reshape(x, [-1,  last_dim, time_steps ]))(vec)

      else:
        vec   = Permute([2,1,3])(vec)
        vec   = Lambda(lambda x:K.reshape(x, [-1, time_steps,  last_dim ]))(vec)

      return vec

    # moves down the timestep dimention towards the batch_size dimention
    def shift_timestep_behind(self,vec,last_dim,time_steps):
      vec    = Lambda(lambda x:K.reshape(x, [-1,self.heads, time_steps,  last_dim ]))(vec)
      vec    = Permute([2,1,3])(vec)

      vec    = Lambda(lambda x:K.reshape(x, [-1,time_steps,self.heads*last_dim ]))(vec)

      return vec

    def scaledDotAttention(self):
        '''
        Scaled dot attention : computes the attention score by dot product of query vector and 
        key vector. Sums the value vectors of tokens based on attention weights( after softmax of attention score )
        '''
        attention_score   = Lambda( lambda x: K.batch_dot(x[0],x[1]) / np.sqrt(self.dim_q))([self.query_vec,self.key_vec])
        attention_weights = Activation('softmax')(attention_score)
        attention_vector  = Lambda( lambda x: K.batch_dot(x[0],x[1]))([attention_weights,self.value_vec])

        return attention_vector, attention_weights

    def __call__(self, x):

        a = x
        time_steps = int(a.get_shape()[1])
        self.query_vec = self.query_layer(a)
        self.key_vec   = self.key_layer(a)
        self.value_vec = self.value_layer(a)

        # Reshape
        self.query_vec = self.shift_timestep_ahead(self.query_vec,self.dim_q,time_steps,transpose = False)
        self.key_vec   = self.shift_timestep_ahead(self.key_vec,self.dim_q,time_steps,transpose = True)
        self.value_vec = self.shift_timestep_ahead(self.value_vec,self.dim_v,time_steps,transpose= False)

        # Attention Weights
        self.attention_vec,self.attention_weights = self.scaledDotAttention()

        # print(self.attention_weights,self.attention_vec)
        self.attention_weights = Lambda( lambda x: K.reshape(x,[-1,self.heads,time_steps,time_steps]))(self.attention_weights)
        self.attention_vec     = Lambda( lambda x: K.reshape(x,[-1,time_steps,self.dim_v]))(self.attention_vec)

        #Output Fully Connected Dense
        temp_out               = self.shift_timestep_behind(self.attention_vec,self.dim_v,time_steps)
        temp_out               = self.dropout_layer(temp_out)
        self.out_vec           = self.output_layer(temp_out)

        return [self.out_vec,self.attention_weights]

# %%
from keras import backend as K
from keras.layers import Layer
import math
import numpy as np
import tensorflow as tf
from keras.initializers import Ones,Zeros

class LayerNormalization(Layer):
    '''
    Layer normalization of the input with trainable gain_parameter and bias parameter
    Source: https://github.com/Lsdefine/attention-is-all-you-need-keras/blob/master/transformer.py#L14
    '''
    def __init__(self, **kwargs):
        super(LayerNormalization, self).__init__(**kwargs)

    def build(self, input_shape):
        self.epsilon   = 1e-6
        self.gain_para = self.add_weight(name='gain_parameter',
                                          shape=[input_shape[1],1],
                                          initializer = Ones(),trainable=True)
        self.bias_para = self.add_weight(name='bias_parameter',
                                          shape=[input_shape[1],1],
                                          initializer = Zeros(),
                                          trainable = True)

        super(LayerNormalization, self).build(input_shape)  # Be sure to call this at the end

    def call(self, x):

        mean = K.mean(x,axis=-1,keepdims=True)
        std  = K.std(x,axis=-1,keepdims=True)

        normalised_vec = ((x-mean) / (std + self.epsilon)) * self.gain_para + self.bias_para
        return normalised_vec

    def compute_output_shape(self, input_shape):
        # assert isinstance(input_shape, list)
        return input_shape

# %%
from keras.layers import TimeDistributed,Dense,Dropout
import keras

class PositionWiseFeedForward():
    '''
        Applies a position wise feed forward dense layer on each token embedding
    '''
    def __init__(self,d_model,inner_dim,dropout_rate,name, **kwargs):

        self.inner_dim     = inner_dim

        self.hidden_layer  = TimeDistributed(Dense(self.inner_dim,activation=keras.activations.relu),name = name+'_PositionWiseFeedForward')
        self.dropout_layer = Dropout(dropout_rate)
        self.out_layer     = TimeDistributed(Dense(d_model),name = name+'_outffn')


    def __call__(self, x):

        self.hidden_vec = self.hidden_layer(x)
        self.hidden_vec = self.dropout_layer(self.hidden_vec)
        self.out_vec    = self.out_layer(self.hidden_vec)

        return self.out_vec

# %%
from keras import backend as K
from keras.layers import Layer
from keras.layers import Add
import math

class TransformerEncoder():
    '''
    Main Transformer Encoder block : Encapsulates different layers with a Transformer Encoder block and calls them in order.
    Inputs
    d_model : dimensions of the output and internal layers
    heads   : number of heads
    dim_q   : query and key dimension 
    dim_v   : value dimension
    hidden_units : hidden units for the positionwise feed forward network
    dropout_rate : dropout_rate

    Outputs
    A tuple:Transformer Encoder Representation, attention weights for each head and token
    '''
    def __init__(self, d_model,heads,dim_q,dim_v,hidden_units,dropout_rate,name,activation='relu', **kwargs):
        self.dim_v        = dim_v
        self.dim_q        = dim_q
        self.hidden_units = hidden_units
        self.heads        = heads

        self.attention_layer      = MultiHeadedAttention(d_model = d_model,heads = self.heads,dim_q = self.dim_q,dim_v = self.dim_v,dropout_rate=dropout_rate,name=name)
        self.normalization_layer  = LayerNormalization()
        self.feedforward          = PositionWiseFeedForward(d_model = d_model,inner_dim = self.hidden_units,dropout_rate=dropout_rate,name=name)


    def __call__(self, x):

        attention_vec,attention_weights   = self.attention_layer(x)
        normalized_inp                    = self.normalization_layer(Add()([attention_vec,x]))
        feedforward_out                   = self.feedforward(normalized_inp)

        transformer_out = self.normalization_layer(Add()([feedforward_out,normalized_inp]))

        return [transformer_out,attention_weights]

# %%
from keras.layers import Layer
class TransformerPositionalEmbedding(Layer):
    """
    Trainable positional embeddings: to be added to the inputs of Transformer block to learn 
    sequence information carried by the sentences.
    """

    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def build(self, input_shape):
        sequence_length, d_model = input_shape[-2:]
        self.position_embeddings = self.add_weight(
            shape=(sequence_length, d_model),
            initializer='uniform',
            name='position_embeddings',
            trainable=True)

        super().build(input_shape)

    def call(self, inputs, **kwargs):
        result = inputs + self.position_embeddings

        return result

# %%
sweep_transformer_config = {
    "method": "random", 
    "metric": {
      "name": "MAPE",
      "goal": "minimize"   
    },
    "parameters": {
        
        "learning_rate": {
            "values": [0.0001, 0.001, 0.005, 0.01]
        },
        "epochs": {
            "values": [100, 150, 200, 300]
        },
        "batch_size": {
            "values": [64, 128]
        },
        "num_heads": {
            "values": [4, 8, 16]
        },
        "num_transformer_blocks": {
            "values": [4, 8]
        },
        "mlp_units": {
            "values":[64, 128, 256]
        },
        "mlp_dropout": {
            "values": [0.2, 0.25, 0.3]
        },
        "dropout": {
            "values": [0.2, 0.25, 0.3]
        },
        "hidden_dim": {
            "values":[100, 150, 200]
        },
        "positional_ff_dim": {
            "values":[64, 128, 256]
        }
    }
}

sweep_id = wandb.sweep(sweep_transformer_config, project="Transformer_shot_6")
# Out:
# Create sweep with ID: xgkgx91p
# Sweep URL: https://wandb.ai/malekkamoua/Transformer_shot_6/sweeps/xgkgx91p

# %%
from datetime import datetime
from time import time 

import tensorflow as tf
import keras
from keras import layers
from keras.models import Model
from keras.models import load_model
from keras.models import Sequential

from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
from keras.callbacks import Callback
from wandb.keras import WandbCallback

from keras.losses import MeanSquaredError, MeanAbsolutePercentageError
from keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

from keras.models import load_model
from keras.utils.vis_utils import plot_model

class Transformer(object):

    def __init__(self):

        self.look_back = 5
        self.n_features = 1
        self.horizon = 1

        self.checkpoint_dir = "checkpoint"

        self.num_heads = wandb.config['num_heads']
        self.num_transformer_blocks = wandb.config['num_transformer_blocks']
        self.mlp_units = [wandb.config['mlp_units']] 
        self.mlp_dropout = wandb.config['mlp_dropout']
        self.dropout = wandb.config['dropout']
        self.hidden_dim =  wandb.config['hidden_dim']  # Number of neurons in each recurrent unit 
        self.positional_ff_dim =  wandb.config['positional_ff_dim']

    def build(self):

        encoder_inputs = Input(shape=(self.look_back, self.n_features),dtype='float32',name='Encoder_input')
        
        positional_embedding_layer    = TransformerPositionalEmbedding(name='Positional_embedding')
        next_step_input               = positional_embedding_layer(encoder_inputs)
        
        for _ in range(self.num_transformer_blocks):
            next_step_input,attention =TransformerEncoder(d_model = self.hidden_dim,
                                                          heads = self.num_heads,
                                                          dim_q = self.hidden_dim,
                                                          dim_v = self.hidden_dim,
                                                          hidden_units = self.positional_ff_dim,
                                                          dropout_rate= self.dropout,
                                                          name= 'Transformer')(next_step_input)
           

        x = layers.GlobalAveragePooling1D(data_format="channels_first")([encoder_inputs])
        for dim in self.mlp_units:
            x = layers.Dense(dim, activation="relu")(x)
            x = layers.Dropout(self.mlp_dropout)(x)

        # output layer
        outputs = layers.Dense(self.horizon)(x)

        return keras.Model(encoder_inputs, outputs)

    
    def train(self, X_train, y_train, epochs, batch_size):

        self.model = self.build()
        self.model.compile( loss = MeanSquaredError(), 
                           optimizer = Adam(learning_rate= wandb.config['learning_rate']), 
                           metrics=['mae',
                                    MeanSquaredError(),
                                    RootMeanSquaredError(),
                                    MeanAbsolutePercentageError()])

        early_stopping_monitor = EarlyStopping(monitor='loss', patience=10, verbose=0, mode='min')
        cp = ModelCheckpoint('./model', save_best_only=True, monitor='loss', mode='min')  

        callback_history = self.model.fit(X_train, y_train,
                                          epochs=epochs,
                                          batch_size=batch_size,
                                          verbose=1,
                                          callbacks=[early_stopping_monitor,
                                                     cp,
                                                     WandbCallback()])

# %%
def train():
  config_defaults = {
    "learning_rate": 0.001,
    "epochs": 100,
    "batch_size": 128,
    "num_heads": 4,
    "num_transformer_blocks": 4,
    "mlp_units": 128,
    "mlp_dropout": 0.2,
    "dropout": 0.25,
    "hidden_dim": 100,
    "positional_ff_dim": 128
  }

  wandb.init(config=config_defaults)  # defaults are over-ridden during the sweep
  config = wandb.config

  ## Testing the Transformer
  tr = Transformer()
  tr.train(X_train,y_train, wandb.config['epochs'], wandb.config['batch_size'])

  y_pred_val = tr.model.predict(np.asarray(X_val).astype('float32'))
  Inverse_y_val = y_val.reshape(-1,1)
  Inverse_y_val = scaler.inverse_transform(Inverse_y_val)
  Inverse_y_pred_val = scaler.inverse_transform(y_pred_val)

  mape, mae, rmse = forecast_accuracy(Inverse_y_pred_val, Inverse_y_val)

  wandb.log({"MAPE": mape, "MAE": mae, "RMSE": rmse})

  filename = './model'
  copyfile(filename, wandb.run.dir) 

  wandb.finish()

# %%
wandb.agent(sweep_id, train, count=1)

# %%
from datetime import datetime
from time import time 

import tensorflow as tf
import keras
from keras import layers
from keras.models import Model
from keras.models import load_model
from keras.models import Sequential

from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
from keras.callbacks import Callback

from keras.losses import MeanSquaredError, MeanAbsolutePercentageError
from keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

from keras.models import load_model
from keras.utils.vis_utils import plot_model

class Transformer(object):

    def __init__(self):

        self.look_back = 5
        self.n_features = 1
        self.horizon = 1

        self.checkpoint_dir = "checkpoint"

        self.num_heads=4
        self.num_transformer_blocks=8
        self.mlp_units=[128]
        self.mlp_dropout=0.25
        self.dropout=0.3
        self.hidden_dim = 1  # Number of neurons in each recurrent unit 
        self.positional_ff_dim = 64
        self.learning_rate = 0.01

    def build(self):

        encoder_inputs = Input(shape=(self.look_back, self.n_features),dtype='float32',name='Encoder_input')
        
        positional_embedding_layer    = TransformerPositionalEmbedding(name='Positional_embedding')
        next_step_input               = positional_embedding_layer(encoder_inputs)
        
        i = 0
        for _ in range(self.num_transformer_blocks):
            next_step_input,attention =TransformerEncoder(d_model = self.hidden_dim,
                                                          heads = self.num_heads,
                                                          dim_q = self.hidden_dim,
                                                          dim_v = self.hidden_dim,
                                                          hidden_units = self.positional_ff_dim,
                                                          dropout_rate= self.dropout,
                                                          name= f'Transformer_{i}')(next_step_input)
           
            i = i + 1
        x = layers.GlobalAveragePooling1D(data_format="channels_first")(next_step_input)
        for dim in self.mlp_units:
            x = layers.Dense(dim, activation="relu")(x)
            x = layers.Dropout(self.mlp_dropout)(x)

        # output layer
        outputs = layers.Dense(self.horizon)(x)

        return keras.Model(encoder_inputs, outputs)


    def train(self, X_train, y_train, epochs, batch_size):

        self.model = self.build()
        self.model.compile( loss = MeanSquaredError(), 
                           optimizer = Adam(learning_rate= self.learning_rate), 
                           metrics=['mae',
                                    MeanSquaredError(),
                                    RootMeanSquaredError(),
                                    MeanAbsolutePercentageError(),
                                    ])

        early_stopping_monitor = EarlyStopping(monitor='loss', patience=10, verbose=0, mode='min')

        callback_history = self.model.fit(X_train, y_train,
                                          epochs=epochs,
                                          batch_size=batch_size,
                                          verbose=1,
                                          validation_data = (X_test, y_test),
                                          callbacks=[early_stopping_monitor])

# %%
import time
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

## Testing the Transformer 
tr = Transformer()      
start = time.time()
tr.train(X_train,y_train, 2, 128)   
stop = time.time()
# Out:
# Train on 3935 samples, validate on 840 samples
# Epoch 1/2
# 3840/3935 [============================>.] - ETA: 0s - loss: 0.1706 - mean_absolute_error: 0.3307 - mean_squared_error: 0.1706 - root_mean_squared_error: 0.4131 - mean_absolute_percentage_error: 66.5604
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 3935/3935 [==============================] - 7s 2ms/sample - loss: 0.1692 - mean_absolute_error: 0.3293 - mean_squared_error: 0.1688 - root_mean_squared_error: 0.4114 - mean_absolute_percentage_error: 66.3393 - val_loss: 0.0585 - val_mean_absolute_error: 0.1802 - val_mean_squared_error: 0.0583 - val_root_mean_squared_error: 0.2419 - val_mean_absolute_percentage_error: 59.4818
# Epoch 2/2
# 3935/3935 [==============================] - 1s 286us/sample - loss: 0.0756 - mean_absolute_error: 0.2322 - mean_squared_error: 0.0755 - root_mean_squared_error: 0.2749 - mean_absolute_percentage_error: 72.1086 - val_loss: 0.0598 - val_mean_absolute_error: 0.2208 - val_mean_squared_error: 0.0593 - val_root_mean_squared_error: 0.2446 - val_mean_absolute_percentage_error: 101.6364

# %%
tr.model.summary()

# %%
from keras.models import load_model
from keras.utils.vis_utils import plot_model

plot_model(tr.model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
print(f"Training time: {stop - start}s")
# Out:
# Training time: 56.18958497047424s

# %%
y_pred_train = tr.model.predict(X_train) 
 
y_pred_train = tr.model.predict(np.asarray(X_train).astype('float32'))
Inverse_y_train = y_train.reshape(-1,1)
Inverse_y_train = scaler.inverse_transform(Inverse_y_train)
Inverse_y_pred_train = scaler.inverse_transform(y_pred_train)
 
mape, mae, rmse = forecast_accuracy(Inverse_y_pred_train, Inverse_y_train)

fig, ax = plt.subplots(figsize=(20,5))
plt.plot(Inverse_y_train[0:100], color='orange')
plt.plot(Inverse_y_pred_train[0:100])
plt.title("Train Predictions with Transformer [RMSE = %.3f, MAPE = %.3f , MAE = %.3f]" % (rmse, mape, mae) )
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
y_pred_test = tr.model.predict(X_test)

y_pred_test = tr.model.predict(np.asarray(X_test).astype('float32'))
Inverse_y_test = y_test.reshape(-1,1)
Inverse_y_test = scaler.inverse_transform(Inverse_y_test)
Inverse_y_pred_test = scaler.inverse_transform(y_pred_test)

mape, mae, rmse = forecast_accuracy(Inverse_y_pred_test, Inverse_y_test)

fig, ax = plt.subplots(figsize=(20,5))
plt.plot(Inverse_y_test[0:100], color='orange')
plt.plot(Inverse_y_pred_test[0:100])
plt.title("Test Predictions with Transformer [RMSE = %.3f, MAPE = %.3f , MAE = %.3f]" % (rmse, mape, mae) )
plt.show()

# %%
y_pred_val = tr.model.predict(X_val)

y_pred_val = tr.model.predict(np.asarray(X_val).astype('float32'))
Inverse_y_val = y_val.reshape(-1,1)
Inverse_y_val = scaler.inverse_transform(Inverse_y_val)
Inverse_y_pred_val = scaler.inverse_transform(y_pred_val)

mape, mae, rmse = forecast_accuracy(Inverse_y_pred_val, Inverse_y_val)

fig, ax = plt.subplots(figsize=(20,5))
plt.plot(Inverse_y_val[0:100], color='orange')
plt.plot(Inverse_y_pred_val[0:100])
plt.title("Validation Predictions with Transformer [RMSE = %.3f, MAPE = %.3f , MAE = %.3f]" % (rmse, mape, mae) )
plt.show()

# %% [markdown]
# ## Save model

# %%
filepath = '/content/gdrive/MyDrive/Datascience/PFE/transformer_model.h5'

# %%
tr.model.save(filepath, save_format="h5")

# %% [markdown]
# ## Testing saved model

# %%
from keras.models import load_model
from keras.utils.vis_utils import plot_model

best_model = load_model(filepath, compile=False)

# %%
from keras.models import load_model
from keras.utils.vis_utils import plot_model

plot_model(best_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
y_pred_val = best_model.predict(np.asarray(X_val).astype('float32'))
Inverse_y_val = y_val.reshape(-1,1)
Inverse_y_val = scaler.inverse_transform(Inverse_y_val)
Inverse_y_pred_val = scaler.inverse_transform(y_pred_val)

mape, mae, rmse = forecast_accuracy(Inverse_y_pred_val, Inverse_y_val)

fig, ax = plt.subplots(figsize=(20,5))
plt.plot(Inverse_y_val, color='orange')
plt.plot(Inverse_y_pred_val)
plt.title("Validation Predictions with Transformer [RMSE = %.3f, MAPE = %.3f , MAE = %.3f]" % (rmse, mape, mae) )
plt.show()

# %%
Inverse_y_pred_val[10].tolist()[0]
# Out:
# 1.7453498840332031

# %%
Inverse_y_val[10].tolist()[0]
# Out:
# 1.6800000000000002

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, InputLayer

from keras.callbacks import ModelCheckpoint
from keras.losses import MeanSquaredError, MeanAbsolutePercentageError
from keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# Define early_stopping_monitor
from keras.callbacks import EarlyStopping
early_stopping_monitor = EarlyStopping(patience=2)

from wandb.keras import WandbCallback

def train():
  config_defaults = {
    "learning_rate": 0.001,
    "epochs": 100,
    "batch_size": 128,
    "num_heads": 4,
    "num_transformer_blocks": 4,
    "mlp_units": 128,
    "mlp_dropout": 0.2,
    "dropout": 0.25,
    "hidden_dim": 100,
    "positional_ff_dim": 128
  }


  wandb.init(config=config_defaults)  # defaults are over-ridden during the sweep
  config = wandb.config

  look_back = 5
  n_features = 1
  horizon = 1

  checkpoint_dir = "checkpoint"

  num_heads = wandb.config['num_heads']
  num_transformer_blocks = wandb.config['num_transformer_blocks']
  mlp_units = [wandb.config['mlp_units']] 
  mlp_dropout = wandb.config['mlp_dropout']
  dropout = wandb.config['dropout']
  hidden_dim =  wandb.config['hidden_dim']  # Number of neurons in each recurrent unit 
  positional_ff_dim =  wandb.config['positional_ff_dim']


  cp = ModelCheckpoint('model/', save_best_only=True)

  encoder_inputs = Input(shape=(look_back, n_features),dtype='float32',name='Encoder_input')
        
  positional_embedding_layer    = TransformerPositionalEmbedding(name='Positional_embedding')
  next_step_input               = positional_embedding_layer(encoder_inputs)
  
  i = 0
  for _ in range(num_transformer_blocks):
      next_step_input,attention =TransformerEncoder(d_model = hidden_dim,
                                                    heads = num_heads,
                                                    dim_q = hidden_dim,
                                                    dim_v = hidden_dim,
                                                    hidden_units = positional_ff_dim,
                                                    dropout_rate= dropout,
                                                    name= f'Transformer_{i}')(next_step_input)
      
      i = i + 1
  x = layers.GlobalAveragePooling1D(data_format="channels_first")(next_step_input)
  for dim in mlp_units:
      x = layers.Dense(dim, activation="relu")(x)
      x = layers.Dropout(mlp_dropout)(x)

  # output layer
  outputs = layers.Dense(horizon)(x)


  model =  keras.Model(encoder_inputs, outputs)
  
  model.compile( loss = MeanSquaredError(), 
                    optimizer = Adam(learning_rate= wandb.config['learning_rate']), 
                    metrics=['mae',
                          MeanSquaredError(),
                          RootMeanSquaredError(),
                          MeanAbsolutePercentageError()])

  history = model.fit(X_train, y_train, 
                      epochs = wandb.config['epochs'] , 
                      batch_size = wandb.config['batch_size'],
                      validation_data=(X_test, y_test),
                      callbacks= [early_stopping_monitor, 
                                  WandbCallback()])  
  
  
  y_pred_val = tr.model.predict(np.asarray(X_val).astype('float32'))
  Inverse_y_val = y_val.reshape(-1,1)
  Inverse_y_val = scaler.inverse_transform(Inverse_y_val)
  Inverse_y_pred_val = scaler.inverse_transform(y_pred_val)

  mape, mae, rmse = forecast_accuracy(Inverse_y_pred_val, Inverse_y_val)

  wandb.log({"MAPE": mape, "MAE": mae, "RMSE": rmse})

  wandb.finish()

# %%
wandb.agent(sweep_id, train, count=1)

# %%
from datetime import datetime
from time import time 

import tensorflow as tf
import keras
from keras import layers
from keras.models import Model
from keras.models import load_model
from keras.models import Sequential

from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
from keras.callbacks import Callback

from keras.losses import MeanSquaredError, MeanAbsolutePercentageError
from keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

from keras.models import load_model
from keras.utils.vis_utils import plot_model

class The_transformer(object):

    def __init__(self):

        self.look_back = 5
        self.n_features = 1
        self.horizon = 1

        self.checkpoint_dir = "checkpoint"

        self.head_size=128
        self.num_heads=4
        self.ff_dim=4
        self.num_transformer_blocks=8
        self.mlp_units=[128]
        self.mlp_dropout=0.25
        self.dropout=0.3


    def transformer_encoder(self,
        inputs):

        # Normalization and Attention
        x = layers.LayerNormalization(epsilon=1e-6)(inputs)
        x = layers.MultiHeadAttention(
        key_dim=self.head_size, num_heads=self.num_heads, dropout=self.dropout)(x, x)
        x = layers.Dropout(self.dropout)(x)

        res = x + inputs

        # Feed Forward Part
        x = layers.LayerNormalization(epsilon=1e-6)(res)
        x = layers.Conv1D(filters=self.ff_dim, kernel_size=1, activation="relu")(x)
        x = layers.Dropout(self.dropout)(x)
        x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
        return x + res


    def build(self):

        inputs = keras.Input(shape=(self.look_back, self.n_features))
        x = inputs
        for _ in range(self.num_transformer_blocks):
            x = self.transformer_encoder(x)

        x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
        for dim in self.mlp_units:
            x = layers.Dense(dim, activation="relu")(x)
            x = layers.Dropout(self.mlp_dropout)(x)

        # output layer
        outputs = layers.Dense(self.horizon)(x)

        return keras.Model(inputs, outputs)

    
    def train(self, X_train, y_train, epochs, batch_size):

        self.model = self.build()
        self.model.compile( loss = MeanSquaredError(), 
                           optimizer = Adam(learning_rate= 0.01), 
                           metrics=['mae',
                                    MeanSquaredError(),
                                    RootMeanSquaredError(),
                                    MeanAbsolutePercentageError()])

        early_stopping_monitor = EarlyStopping(monitor="loss",
                                               min_delta=0.001,
                                               patience=3,
                                               mode="min",
                                               verbose=1)

        # Save the best model ... with minimal error
        filepath = self.checkpoint_dir+"/Transformer.best"+datetime.now().strftime('%d%m%Y_%H:%M:%S')+".hdf5"
        cp = ModelCheckpoint(filepath,
                                     monitor=MeanAbsolutePercentageError(),
                                     verbose=1,
                                     save_best_only=True,
                                     mode='min')

        callback_history = self.model.fit(X_train, y_train,
                                          epochs=epochs,
                                          batch_size=batch_size,
                                          verbose=1,
                                          callbacks=[early_stopping_monitor,
                                                     cp])

# %%
import time

model = The_transformer()       
start = time.time()
model.train(X_train,y_train, 150, 128)
stop = time.time()
# Out:
# Error in callback <bound method _WandbInit._resume_backend of <wandb.sdk.wandb_init._WandbInit object at 0x7f1cf7aa4090>> (for pre_run_cell):
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py in _resume_backend(self)
#     349         if self.backend is not None:
#     350             logger.info("resuming backend")
# --> 351             self.backend.interface.publish_resume()
#     352
#     353     def _jupyter_teardown(self):
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface.py in publish_resume(self)
#     615     def publish_resume(self) -> None:
#     616         resume = pb.ResumeRequest()
# --> 617         self._publish_resume(resume)
#     618
#     619     @abstractmethod
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_shared.py in _publish_resume(self, resume)
#     281     def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     282         rec = self._make_request(resume=resume)
# --> 283         self._publish(rec)
#     284
#     285     def _publish_run(self, run: pb.RunRecord) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_queue.py in _publish(self, record, local)
#      47     def _publish(self, record: "pb.Record", local: bool = None) -> None:
#      48         if self._process_check and self._process and not self._process.is_alive():
# ---> 49             raise Exception("The wandb backend process has shutdown")
#      50         if local:
#      51             record.control.local = local
#
# Exception: The wandb backend process has shutdown
# Train on 3935 samples
# Epoch 1/150

# %%
print(f"Training time: {stop - start}s")

# %%
y_pred_val = model.model.predict(X_val)

y_pred_val = model.model.predict(np.asarray(X_val).astype('float32'))
Inverse_y_val = y_val.reshape(-1,1)
Inverse_y_val = scaler.inverse_transform(Inverse_y_val)
Inverse_y_pred_val = scaler.inverse_transform(y_pred_val)

mape, mae, rmse = forecast_accuracy(Inverse_y_pred_val, Inverse_y_val)

fig, ax = plt.subplots(figsize=(20,5))
plt.plot(Inverse_y_val[0:100], color='orange')
plt.plot(Inverse_y_pred_val[0:100])
plt.title("Validation Predictions with Transformer [RMSE = %.3f, MAPE = %.3f , MAE = %.3f]" % (rmse, mape, mae) )
plt.show()

# %%
model.model.summary()
# Out:
# Model: "model_34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 5, 1)]       0           []
#
#  layer_normalization_336 (Layer  (None, 5, 1)        2           ['input_5[0][0]']
#  Normalization)
#
#  multi_head_attention_8 (MultiH  (None, 5, 1)        14337       ['layer_normalization_336[0][0]',
#  eadAttention)                                                    'layer_normalization_336[0][0]']
#
#  dropout_686 (Dropout)          (None, 5, 1)         0           ['multi_head_attention_8[0][0]']
#
#  tf_op_layer_add_16 (TensorFlow  [(None, 5, 1)]      0           ['dropout_686[0][0]',
#  OpLayer)                                                         'input_5[0][0]']
#
#  layer_normalization_337 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_16[0][0]']
#  Normalization)
#
#  conv1d_16 (Conv1D)             (None, 5, 4)         8           ['layer_normalization_337[0][0]']
#
#  dropout_687 (Dropout)          (None, 5, 4)         0           ['conv1d_16[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 5, 1)         5           ['dropout_687[0][0]']
#
#  tf_op_layer_add_17 (TensorFlow  [(None, 5, 1)]      0           ['conv1d_17[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_16[0][0]']
#
#  layer_normalization_338 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_17[0][0]']
#  Normalization)
#
#  multi_head_attention_9 (MultiH  (None, 5, 1)        14337       ['layer_normalization_338[0][0]',
#  eadAttention)                                                    'layer_normalization_338[0][0]']
#
#  dropout_689 (Dropout)          (None, 5, 1)         0           ['multi_head_attention_9[0][0]']
#
#  tf_op_layer_add_18 (TensorFlow  [(None, 5, 1)]      0           ['dropout_689[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_17[0][0]']
#
#  layer_normalization_339 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_18[0][0]']
#  Normalization)
#
#  conv1d_18 (Conv1D)             (None, 5, 4)         8           ['layer_normalization_339[0][0]']
#
#  dropout_690 (Dropout)          (None, 5, 4)         0           ['conv1d_18[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 5, 1)         5           ['dropout_690[0][0]']
#
#  tf_op_layer_add_19 (TensorFlow  [(None, 5, 1)]      0           ['conv1d_19[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_18[0][0]']
#
#  layer_normalization_340 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_19[0][0]']
#  Normalization)
#
#  multi_head_attention_10 (Multi  (None, 5, 1)        14337       ['layer_normalization_340[0][0]',
#  HeadAttention)                                                   'layer_normalization_340[0][0]']
#
#  dropout_692 (Dropout)          (None, 5, 1)         0           ['multi_head_attention_10[0][0]']
#
#  tf_op_layer_add_20 (TensorFlow  [(None, 5, 1)]      0           ['dropout_692[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_19[0][0]']
#
#  layer_normalization_341 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_20[0][0]']
#  Normalization)
#
#  conv1d_20 (Conv1D)             (None, 5, 4)         8           ['layer_normalization_341[0][0]']
#
#  dropout_693 (Dropout)          (None, 5, 4)         0           ['conv1d_20[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 5, 1)         5           ['dropout_693[0][0]']
#
#  tf_op_layer_add_21 (TensorFlow  [(None, 5, 1)]      0           ['conv1d_21[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_20[0][0]']
#
#  layer_normalization_342 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_21[0][0]']
#  Normalization)
#
#  multi_head_attention_11 (Multi  (None, 5, 1)        14337       ['layer_normalization_342[0][0]',
#  HeadAttention)                                                   'layer_normalization_342[0][0]']
#
#  dropout_695 (Dropout)          (None, 5, 1)         0           ['multi_head_attention_11[0][0]']
#
#  tf_op_layer_add_22 (TensorFlow  [(None, 5, 1)]      0           ['dropout_695[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_21[0][0]']
#
#  layer_normalization_343 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_22[0][0]']
#  Normalization)
#
#  conv1d_22 (Conv1D)             (None, 5, 4)         8           ['layer_normalization_343[0][0]']
#
#  dropout_696 (Dropout)          (None, 5, 4)         0           ['conv1d_22[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 5, 1)         5           ['dropout_696[0][0]']
#
#  tf_op_layer_add_23 (TensorFlow  [(None, 5, 1)]      0           ['conv1d_23[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_22[0][0]']
#
#  layer_normalization_344 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_23[0][0]']
#  Normalization)
#
#  multi_head_attention_12 (Multi  (None, 5, 1)        14337       ['layer_normalization_344[0][0]',
#  HeadAttention)                                                   'layer_normalization_344[0][0]']
#
#  dropout_698 (Dropout)          (None, 5, 1)         0           ['multi_head_attention_12[0][0]']
#
#  tf_op_layer_add_24 (TensorFlow  [(None, 5, 1)]      0           ['dropout_698[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_23[0][0]']
#
#  layer_normalization_345 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_24[0][0]']
#  Normalization)
#
#  conv1d_24 (Conv1D)             (None, 5, 4)         8           ['layer_normalization_345[0][0]']
#
#  dropout_699 (Dropout)          (None, 5, 4)         0           ['conv1d_24[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 5, 1)         5           ['dropout_699[0][0]']
#
#  tf_op_layer_add_25 (TensorFlow  [(None, 5, 1)]      0           ['conv1d_25[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_24[0][0]']
#
#  layer_normalization_346 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_25[0][0]']
#  Normalization)
#
#  multi_head_attention_13 (Multi  (None, 5, 1)        14337       ['layer_normalization_346[0][0]',
#  HeadAttention)                                                   'layer_normalization_346[0][0]']
#
#  dropout_701 (Dropout)          (None, 5, 1)         0           ['multi_head_attention_13[0][0]']
#
#  tf_op_layer_add_26 (TensorFlow  [(None, 5, 1)]      0           ['dropout_701[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_25[0][0]']
#
#  layer_normalization_347 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_26[0][0]']
#  Normalization)
#
#  conv1d_26 (Conv1D)             (None, 5, 4)         8           ['layer_normalization_347[0][0]']
#
#  dropout_702 (Dropout)          (None, 5, 4)         0           ['conv1d_26[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 5, 1)         5           ['dropout_702[0][0]']
#
#  tf_op_layer_add_27 (TensorFlow  [(None, 5, 1)]      0           ['conv1d_27[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_26[0][0]']
#
#  layer_normalization_348 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_27[0][0]']
#  Normalization)
#
#  multi_head_attention_14 (Multi  (None, 5, 1)        14337       ['layer_normalization_348[0][0]',
#  HeadAttention)                                                   'layer_normalization_348[0][0]']
#
#  dropout_704 (Dropout)          (None, 5, 1)         0           ['multi_head_attention_14[0][0]']
#
#  tf_op_layer_add_28 (TensorFlow  [(None, 5, 1)]      0           ['dropout_704[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_27[0][0]']
#
#  layer_normalization_349 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_28[0][0]']
#  Normalization)
#
#  conv1d_28 (Conv1D)             (None, 5, 4)         8           ['layer_normalization_349[0][0]']
#
#  dropout_705 (Dropout)          (None, 5, 4)         0           ['conv1d_28[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 5, 1)         5           ['dropout_705[0][0]']
#
#  tf_op_layer_add_29 (TensorFlow  [(None, 5, 1)]      0           ['conv1d_29[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_28[0][0]']
#
#  layer_normalization_350 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_29[0][0]']
#  Normalization)
#
#  multi_head_attention_15 (Multi  (None, 5, 1)        14337       ['layer_normalization_350[0][0]',
#  HeadAttention)                                                   'layer_normalization_350[0][0]']
#
#  dropout_707 (Dropout)          (None, 5, 1)         0           ['multi_head_attention_15[0][0]']
#
#  tf_op_layer_add_30 (TensorFlow  [(None, 5, 1)]      0           ['dropout_707[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_29[0][0]']
#
#  layer_normalization_351 (Layer  (None, 5, 1)        2           ['tf_op_layer_add_30[0][0]']
#  Normalization)
#
#  conv1d_30 (Conv1D)             (None, 5, 4)         8           ['layer_normalization_351[0][0]']
#
#  dropout_708 (Dropout)          (None, 5, 4)         0           ['conv1d_30[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 5, 1)         5           ['dropout_708[0][0]']
#
#  tf_op_layer_add_31 (TensorFlow  [(None, 5, 1)]      0           ['conv1d_31[0][0]',
#  OpLayer)                                                         'tf_op_layer_add_30[0][0]']
#
#  global_average_pooling1d_21 (G  (None, 5)           0           ['tf_op_layer_add_31[0][0]']
#  lobalAveragePooling1D)
#
#  dense_1978 (Dense)             (None, 256)          1536        ['global_average_pooling1d_21[0][
#                                                                  0]']
#
#  dropout_709 (Dropout)          (None, 256)          0           ['dense_1978[0][0]']
#
#  dense_1979 (Dense)             (None, 1)            257         ['dropout_709[0][0]']
#
# ==================================================================================================
# Total params: 116,625
# Trainable params: 116,625
# Non-trainable params: 0
# __________________________________________________________________________________________________
